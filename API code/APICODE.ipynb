# %%
import os
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import gmaps
from pprint import pprint
import datetime

# %%
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
#         if len(cities)<100:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 615

# %%
new_cities = []
cloudiness = []
country = []
date = []
humidity = []
temp = []
lat = []
lng = []
wind = []

# %%
api_key='1cdc9d399acb2599e977cf6d6763d8ed'

# %%
record_counter = 0
set_counter = 0
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 
print('------------------------')
print('Beginning Data Retrieval')
print('------------------------')

for city in cities:
    query_url = url + "&q=" + city
    # Get weather data
    response = requests.get(query_url).json()
    if record_counter < 50:
        record_counter += 1
    else:
        set_counter += 1
        record_counter = 0

    print('Processing record {} of set {} | {}'.format(record_counter, set_counter, city))
    print(url)
    try:
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        temp.append(response['main']['temp_max'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        wind.append(response['wind']['speed'])
        new_cities.append(city)
    except:
        print("City not found!")
        pass

print('-------------------------')
print('Data Retrieval Complete')
print('-------------------------')
# Out:
# ------------------------
# Beginning Data Retrieval
# ------------------------
# Processing record 1 of set 0 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 2 of set 0 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 3 of set 0 | nambucca heads
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 4 of set 0 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 5 of set 0 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 6 of set 0 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 7 of set 0 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 8 of set 0 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 9 of set 0 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 10 of set 0 | laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 11 of set 0 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 12 of set 0 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 13 of set 0 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 14 of set 0 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 15 of set 0 | margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 16 of set 0 | machala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 17 of set 0 | shenjiamen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 18 of set 0 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 19 of set 0 | itapira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 20 of set 0 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 21 of set 0 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 22 of set 0 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 23 of set 0 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 24 of set 0 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 25 of set 0 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 26 of set 0 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 27 of set 0 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 28 of set 0 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 29 of set 0 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 30 of set 0 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 31 of set 0 | boguchany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 32 of set 0 | pedernales
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 33 of set 0 | tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 34 of set 0 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 35 of set 0 | smolenskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 36 of set 0 | areosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 37 of set 0 | vinkovci
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 38 of set 0 | champerico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 39 of set 0 | rungata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 40 of set 0 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 41 of set 0 | luganville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 42 of set 0 | bardiyah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 43 of set 0 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 44 of set 0 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 45 of set 0 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 46 of set 0 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 47 of set 0 | groa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 48 of set 0 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 49 of set 0 | solovetskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 50 of set 0 | bonthe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 0 of set 1 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 1 of set 1 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 2 of set 1 | mount isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 3 of set 1 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 4 of set 1 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 5 of set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 6 of set 1 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 7 of set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 8 of set 1 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 9 of set 1 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 10 of set 1 | shahr-e babak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 11 of set 1 | micheweni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 12 of set 1 | duz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 13 of set 1 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 14 of set 1 | morant bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 15 of set 1 | isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 16 of set 1 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 17 of set 1 | dhidhdhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 18 of set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 19 of set 1 | lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 20 of set 1 | pijijiapan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 21 of set 1 | paita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 22 of set 1 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 23 of set 1 | havoysund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 24 of set 1 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 25 of set 1 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 26 of set 1 | atherton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 27 of set 1 | nong bua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 28 of set 1 | kathmandu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 29 of set 1 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 30 of set 1 | yumen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 31 of set 1 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 32 of set 1 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 33 of set 1 | vila velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 34 of set 1 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 35 of set 1 | price
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 36 of set 1 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 37 of set 1 | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 38 of set 1 | katiola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 39 of set 1 | erenhot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 40 of set 1 | koygorodok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 41 of set 1 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 42 of set 1 | bargal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 43 of set 1 | chapleau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 44 of set 1 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 45 of set 1 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 46 of set 1 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 47 of set 1 | sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 48 of set 1 | vaitape
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 49 of set 1 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 50 of set 1 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 0 of set 2 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 1 of set 2 | denpasar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 2 of set 2 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 3 of set 2 | hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 4 of set 2 | reconquista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 5 of set 2 | svetlogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 6 of set 2 | amderma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 7 of set 2 | havelock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 8 of set 2 | kerman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 9 of set 2 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 10 of set 2 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 11 of set 2 | pangody
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 12 of set 2 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 13 of set 2 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 14 of set 2 | alyangula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 15 of set 2 | linxia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 16 of set 2 | iquique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 17 of set 2 | governador dix-sept rosado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 18 of set 2 | totoral
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 19 of set 2 | dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 20 of set 2 | tumannyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 21 of set 2 | llanes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 22 of set 2 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 23 of set 2 | monrovia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 24 of set 2 | bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 25 of set 2 | broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 26 of set 2 | paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 27 of set 2 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 28 of set 2 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 29 of set 2 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 30 of set 2 | grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 31 of set 2 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 32 of set 2 | ilanskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 33 of set 2 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 34 of set 2 | padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 35 of set 2 | putyatino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 36 of set 2 | takoradi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 37 of set 2 | yakeshi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 38 of set 2 | ust-maya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 39 of set 2 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 40 of set 2 | saint-georges
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 41 of set 2 | yarada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 42 of set 2 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 43 of set 2 | shimoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 44 of set 2 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 45 of set 2 | pistsovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 46 of set 2 | macamic
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 47 of set 2 | sorong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 48 of set 2 | arlit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 49 of set 2 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 50 of set 2 | merauke
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 0 of set 3 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 1 of set 3 | ornskoldsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 2 of set 3 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 3 of set 3 | okitipupa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 4 of set 3 | namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 5 of set 3 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 6 of set 3 | port shepstone
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 7 of set 3 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 8 of set 3 | hovd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 9 of set 3 | napier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 10 of set 3 | mazamet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 11 of set 3 | bambanglipuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 12 of set 3 | sinaloa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 13 of set 3 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 14 of set 3 | samusu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 15 of set 3 | daru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 16 of set 3 | coahuayana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 17 of set 3 | kualakapuas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 18 of set 3 | nicoya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 19 of set 3 | te anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 20 of set 3 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 21 of set 3 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 22 of set 3 | mosquera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 23 of set 3 | mwinilunga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 24 of set 3 | nenjiang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 25 of set 3 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 26 of set 3 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 27 of set 3 | ceres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 28 of set 3 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 29 of set 3 | fort nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 30 of set 3 | santander
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 31 of set 3 | iranshahr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 32 of set 3 | kysyl-syr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 33 of set 3 | cherdyn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 34 of set 3 | biritiba-mirim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 35 of set 3 | pinawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 36 of set 3 | soltsy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 37 of set 3 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 38 of set 3 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 39 of set 3 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 40 of set 3 | husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 41 of set 3 | ligayan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 42 of set 3 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 43 of set 3 | avdon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 44 of set 3 | kalaleh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 45 of set 3 | grootfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 46 of set 3 | rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 47 of set 3 | yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 48 of set 3 | vytegra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 49 of set 3 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 50 of set 3 | coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 0 of set 4 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 1 of set 4 | saleaula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 2 of set 4 | champasak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 3 of set 4 | khasan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 4 of set 4 | young
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 5 of set 4 | moissac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 6 of set 4 | ca mau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 7 of set 4 | camana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 8 of set 4 | vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 9 of set 4 | korla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 10 of set 4 | pimentel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 11 of set 4 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 12 of set 4 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 13 of set 4 | ardistan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 14 of set 4 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 15 of set 4 | kaeo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 16 of set 4 | ulaangom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 17 of set 4 | pirgos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 18 of set 4 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 19 of set 4 | huarmey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 20 of set 4 | inuvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 21 of set 4 | araouane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 22 of set 4 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 23 of set 4 | akdepe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 24 of set 4 | vanavara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 25 of set 4 | tashla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 26 of set 4 | kwinana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 27 of set 4 | fairview
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 28 of set 4 | barra do garcas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 29 of set 4 | manggar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 30 of set 4 | buchanan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 31 of set 4 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 32 of set 4 | carauari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 33 of set 4 | dhanera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 34 of set 4 | karasburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 35 of set 4 | saint-francois
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 36 of set 4 | luba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 37 of set 4 | zonguldak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 38 of set 4 | codo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 39 of set 4 | nyrob
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 40 of set 4 | karakendzha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 41 of set 4 | srandakan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 42 of set 4 | cabedelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 43 of set 4 | bandar-e lengeh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 44 of set 4 | cochrane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 45 of set 4 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 46 of set 4 | bosaso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 47 of set 4 | simi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 48 of set 4 | nyurba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 49 of set 4 | ushtobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 50 of set 4 | alghero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 0 of set 5 | yuzhno-yeniseyskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 1 of set 5 | haibowan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 2 of set 5 | hamburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 3 of set 5 | hermiston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 4 of set 5 | pitimbu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 5 of set 5 | glace bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 6 of set 5 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 7 of set 5 | tiruvottiyur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 8 of set 5 | valparaiso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 9 of set 5 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 10 of set 5 | hit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 11 of set 5 | grand centre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 12 of set 5 | san pedro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 13 of set 5 | fukuma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 14 of set 5 | feijo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 15 of set 5 | pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 16 of set 5 | shieli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 17 of set 5 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 18 of set 5 | viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 19 of set 5 | kasungu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 20 of set 5 | dehloran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 21 of set 5 | coronado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 22 of set 5 | ponta delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 23 of set 5 | bereda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 24 of set 5 | mergui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 25 of set 5 | byron bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 26 of set 5 | richards bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 27 of set 5 | honiara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 28 of set 5 | urumqi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 29 of set 5 | kaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 30 of set 5 | bemidji
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 31 of set 5 | oulainen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 32 of set 5 | maceio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 33 of set 5 | south burlington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 34 of set 5 | elko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 35 of set 5 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 36 of set 5 | calvinia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 37 of set 5 | hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 38 of set 5 | matagami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 39 of set 5 | kailua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 40 of set 5 | lovozero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 41 of set 5 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 42 of set 5 | misrikh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 43 of set 5 | bodoco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 44 of set 5 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 45 of set 5 | vila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 46 of set 5 | saint joseph
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 47 of set 5 | balimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 48 of set 5 | aksarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 49 of set 5 | itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 50 of set 5 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 0 of set 6 | nurota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 1 of set 6 | chimbote
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 2 of set 6 | neiafu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 3 of set 6 | kochi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 4 of set 6 | waddan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 5 of set 6 | serafimovich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 6 of set 6 | buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 7 of set 6 | dwarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 8 of set 6 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 9 of set 6 | tocopilla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 10 of set 6 | buluang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 11 of set 6 | kuching
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 12 of set 6 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 13 of set 6 | rio verde de mato grosso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 14 of set 6 | umzimvubu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 15 of set 6 | keetmanshoop
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 16 of set 6 | lifford
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 17 of set 6 | puerto baquerizo moreno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 18 of set 6 | nosy varika
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 19 of set 6 | la rioja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 20 of set 6 | doctor pedro p. pena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 21 of set 6 | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 22 of set 6 | rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 23 of set 6 | awjilah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 24 of set 6 | cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 25 of set 6 | ngukurr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 26 of set 6 | sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 27 of set 6 | vegreville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 28 of set 6 | aasiaat
# ...
# Processing record 2 of set 7 | dunkwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 3 of set 7 | kidal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 4 of set 7 | maniwaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 5 of set 7 | kupang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 6 of set 7 | watertown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 7 of set 7 | korem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 8 of set 7 | porto nacional
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 9 of set 7 | spirit river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 10 of set 7 | levelland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 11 of set 7 | chaa-khol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 12 of set 7 | tokzar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 13 of set 7 | pontes e lacerda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 14 of set 7 | sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 15 of set 7 | ituango
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 16 of set 7 | machida
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 17 of set 7 | kabare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 18 of set 7 | labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 19 of set 7 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 20 of set 7 | sivas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 21 of set 7 | matara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 22 of set 7 | nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 23 of set 7 | orotukan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 24 of set 7 | pangai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 25 of set 7 | gulshat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 26 of set 7 | nassau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 27 of set 7 | cotabato
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 28 of set 7 | muyezerskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 29 of set 7 | raga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 30 of set 7 | hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 31 of set 7 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 32 of set 7 | coos bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 33 of set 7 | cacimba de dentro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 34 of set 7 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 35 of set 7 | college
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 36 of set 7 | lom sak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 37 of set 7 | bonnyville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 38 of set 7 | verkhnetulomskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 39 of set 7 | san juan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 40 of set 7 | besikduzu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 41 of set 7 | kjollefjord
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 42 of set 7 | vanimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 43 of set 7 | fukue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 44 of set 7 | thunder bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 45 of set 7 | mpongwe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 46 of set 7 | goderich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 47 of set 7 | mumford
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 48 of set 7 | teahupoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 49 of set 7 | stykkisholmur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 50 of set 7 | taksimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 0 of set 8 | barcelos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 1 of set 8 | mareeba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 2 of set 8 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 3 of set 8 | yanggu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 4 of set 8 | khartoum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 5 of set 8 | marystown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 6 of set 8 | fos-sur-mer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 7 of set 8 | sakakah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 8 of set 8 | toliary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 9 of set 8 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 10 of set 8 | port macquarie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 11 of set 8 | mogadishu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 12 of set 8 | elbistan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 13 of set 8 | usagara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 14 of set 8 | hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 15 of set 8 | mugumu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 16 of set 8 | nardaran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 17 of set 8 | scottsburgh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 18 of set 8 | mattawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 19 of set 8 | balsas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 20 of set 8 | touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 21 of set 8 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 22 of set 8 | hare bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 23 of set 8 | sao miguel do araguaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 24 of set 8 | agbannawag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 25 of set 8 | richmond
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 26 of set 8 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 27 of set 8 | bur gabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 28 of set 8 | kamenka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 29 of set 8 | muli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 30 of set 8 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 31 of set 8 | chegdomyn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 32 of set 8 | gamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 33 of set 8 | ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 34 of set 8 | broken hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 35 of set 8 | chyhyryn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 36 of set 8 | barillas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 37 of set 8 | bogorodskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 38 of set 8 | mme
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 39 of set 8 | boyolangu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 40 of set 8 | hay river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 41 of set 8 | gijon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 42 of set 8 | houlton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 43 of set 8 | ndele
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 44 of set 8 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 45 of set 8 | maryville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 46 of set 8 | lolua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 47 of set 8 | bowen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 48 of set 8 | ola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 49 of set 8 | halalo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 50 of set 8 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 0 of set 9 | winnemucca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 1 of set 9 | weston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 2 of set 9 | san andres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 3 of set 9 | cacoal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 4 of set 9 | bulalacao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 5 of set 9 | andevoranto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 6 of set 9 | kaseda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 7 of set 9 | aswan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 8 of set 9 | eidfjord
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 9 of set 9 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 10 of set 9 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!

# %%
# create a data frame from cities, temp, humidity, cloudiness and wind speed
weather_dict = {
    "City": new_cities,
    "Cloudiness" : cloudiness,
    "Country" : country,
    "Date" : date,
    "Humidity" : humidity,
    "Temp": temp,
    "Lat" : lat,
    "Lng" : lng,   
    "Wind Speed" : wind
}
weather_data = pd.DataFrame(weather_dict)
weather_data.count()

# %%
weather_data.head()

# %%
cities_list = zip(new_cities,cloudiness,country,date,humidity,temp,lat,lng)
# Set variable for output file
output_file = os.path.join('..', 'API code', 'cities.csv')
#  Open the output file
with open(output_file, 'w') as datafile:
    weather_data.to_csv(output_file)

# %%
date =datetime.datetime.fromtimestamp(
        int(weather_data['Date'][0])
    ).strftime('%m/%d/%Y')

# %%
# Latitude Vs Temperature Plot

weather_data.plot(kind='scatter', x='Lat', y='Temp', c='DarkBlue')
plt.title('City Latitude Vs Max Temperature ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Max temperature (F)')
plt.grid()

# %%
# Latitude Vs Humidity

weather_data.plot(kind='scatter',x='Lat',y='Humidity', c='DarkBlue')
plt.title('City Latitude Vs Max Humidity ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()

# %%
# Latitude Vs Cloudiness

weather_data.plot(kind='scatter',x='Lat',y='Cloudiness', c='DarkBlue')
plt.title('City Latitude Vs Cloudiness ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()

# %%
# Latitude Vs Wind Speed

weather_data.plot(kind='scatter',x='Lat',y='Wind Speed', c='DarkBlue')
plt.title('City Latitude Vs Wind Speed ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid()
