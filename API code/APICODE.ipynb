# %%
import os
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import gmaps
from pprint import pprint
import datetime

# %%
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
#         if len(cities)<100:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 629

# %%
new_cities = []
cloudiness = []
country = []
date = []
humidity = []
temp = []
lat = []
lng = []
wind = []

# %%
api_key='1cdc9d399acb2599e977cf6d6763d8ed'

# %%
record_counter = 0
set_counter = 0
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 
print('------------------------')
print('Beginning Data Retrieval')
print('------------------------')

for city in cities:
    query_url = url + "&q=" + city
    # Get weather data
    response = requests.get(query_url).json()
    if record_counter < 50:
        record_counter += 1
    else:
        set_counter += 1
        record_counter = 0

    print('Processing record {} of set {} | {}'.format(record_counter, set_counter, city))
    print(url)
    try:
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        temp.append(response['main']['temp_max'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        wind.append(response['wind']['speed'])
        new_cities.append(city)
    except:
        print("City not found!")
        pass

print('-------------------------')
print('Data Retrieval Complete')
print('-------------------------')
# Out:
# ------------------------
# Beginning Data Retrieval
# ------------------------
# Processing record 1 of set 0 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 2 of set 0 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 3 of set 0 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 4 of set 0 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 5 of set 0 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 6 of set 0 | chara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 7 of set 0 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 8 of set 0 | udachnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 9 of set 0 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 10 of set 0 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 11 of set 0 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 12 of set 0 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 13 of set 0 | burica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 14 of set 0 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 15 of set 0 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 16 of set 0 | datong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 17 of set 0 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 18 of set 0 | crab hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 19 of set 0 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 20 of set 0 | mazatlan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 21 of set 0 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 22 of set 0 | karlskoga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 23 of set 0 | moron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 24 of set 0 | rovaniemi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 25 of set 0 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 26 of set 0 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 27 of set 0 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 28 of set 0 | marcona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 29 of set 0 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 30 of set 0 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 31 of set 0 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 32 of set 0 | sajalices
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 33 of set 0 | careiro da varzea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 34 of set 0 | tagusao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 35 of set 0 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 36 of set 0 | meyungs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 37 of set 0 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 38 of set 0 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 39 of set 0 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 40 of set 0 | viligili
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 41 of set 0 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 42 of set 0 | amazar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 43 of set 0 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 44 of set 0 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 45 of set 0 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 46 of set 0 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 47 of set 0 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 48 of set 0 | ilhabela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 49 of set 0 | fuyu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 50 of set 0 | necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 0 of set 1 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 1 of set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 2 of set 1 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 3 of set 1 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 4 of set 1 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 5 of set 1 | jinchengjiang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 6 of set 1 | hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 7 of set 1 | mercedes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 8 of set 1 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 9 of set 1 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 10 of set 1 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 11 of set 1 | qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 12 of set 1 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 13 of set 1 | broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 14 of set 1 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 15 of set 1 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 16 of set 1 | dubbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 17 of set 1 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 18 of set 1 | baraki barak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 19 of set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 20 of set 1 | altamira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 21 of set 1 | laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 22 of set 1 | bud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 23 of set 1 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 24 of set 1 | shestakovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 25 of set 1 | dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 26 of set 1 | katangli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 27 of set 1 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 28 of set 1 | mogadishu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 29 of set 1 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 30 of set 1 | milkovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 31 of set 1 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 32 of set 1 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 33 of set 1 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 34 of set 1 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 35 of set 1 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 36 of set 1 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 37 of set 1 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 38 of set 1 | bossangoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 39 of set 1 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 40 of set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 41 of set 1 | jining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 42 of set 1 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 43 of set 1 | takestan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 44 of set 1 | vila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 45 of set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 46 of set 1 | beisfjord
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 47 of set 1 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 48 of set 1 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 49 of set 1 | marabba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 50 of set 1 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 0 of set 2 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 1 of set 2 | tumannyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 2 of set 2 | talcahuano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 3 of set 2 | paita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 4 of set 2 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 5 of set 2 | llanes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 6 of set 2 | mandalgovi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 7 of set 2 | usinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 8 of set 2 | sebinkarahisar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 9 of set 2 | palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 10 of set 2 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 11 of set 2 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 12 of set 2 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 13 of set 2 | tromso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 14 of set 2 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 15 of set 2 | katiola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 16 of set 2 | abidjan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 17 of set 2 | luba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 18 of set 2 | yeppoon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 19 of set 2 | hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 20 of set 2 | dzilam gonzalez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 21 of set 2 | naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 22 of set 2 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 23 of set 2 | itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 24 of set 2 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 25 of set 2 | atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 26 of set 2 | aykhal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 27 of set 2 | nalut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 28 of set 2 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 29 of set 2 | otuzco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 30 of set 2 | havoysund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 31 of set 2 | petersburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 32 of set 2 | xuddur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 33 of set 2 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 34 of set 2 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 35 of set 2 | puerto narino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 36 of set 2 | poltavka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 37 of set 2 | madaoua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 38 of set 2 | poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 39 of set 2 | paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 40 of set 2 | vanimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 41 of set 2 | alenquer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 42 of set 2 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 43 of set 2 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 44 of set 2 | gizo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 45 of set 2 | wasilla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 46 of set 2 | the valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 47 of set 2 | berbera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 48 of set 2 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 49 of set 2 | aswan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 50 of set 2 | maarianhamina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 0 of set 3 | campo bom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 1 of set 3 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 2 of set 3 | padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 3 of set 3 | mildura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 4 of set 3 | brae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 5 of set 3 | roald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 6 of set 3 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 7 of set 3 | whyalla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 8 of set 3 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 9 of set 3 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 10 of set 3 | finschhafen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 11 of set 3 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 12 of set 3 | inta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 13 of set 3 | broken hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 14 of set 3 | adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 15 of set 3 | cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 16 of set 3 | vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 17 of set 3 | dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 18 of set 3 | manaus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 19 of set 3 | aripuana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 20 of set 3 | dmitriyevka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 21 of set 3 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 22 of set 3 | laurens
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 23 of set 3 | cermei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 24 of set 3 | saint-francois
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 25 of set 3 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 26 of set 3 | togur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 27 of set 3 | canaries
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 28 of set 3 | banda aceh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 29 of set 3 | cochrane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 30 of set 3 | rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 31 of set 3 | avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 32 of set 3 | sept-iles
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 33 of set 3 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 34 of set 3 | kuche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 35 of set 3 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 36 of set 3 | dong xoai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 37 of set 3 | kiunga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 38 of set 3 | patiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 39 of set 3 | baherden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 40 of set 3 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 41 of set 3 | djibo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 42 of set 3 | umzimvubu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 43 of set 3 | kimbe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 44 of set 3 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 45 of set 3 | macas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 46 of set 3 | americo brasiliense
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 47 of set
| fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 31 of set 11 | warrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 32 of set 11 | waikuku
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 33 of set 11 | andenes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 34 of set 11 | okato
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 35 of set 11 | muzhi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 36 of set 11 | richards bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 37 of set 11 | prokhorovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 38 of set 11 | aurillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 39 of set 11 | mosalsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 40 of set 11 | namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 41 of set 11 | ayolas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 42 of set 11 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 43 of set 11 | waipawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 44 of set 11 | nova olinda do norte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 45 of set 11 | las vegas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 46 of set 11 | kilindoni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 47 of set 11 | tukrah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 48 of set 11 | yuscaran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 49 of set 11 | yaan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 50 of set 11 | maldonado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 0 of set 12 | beohari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 1 of set 12 | ritchie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 2 of set 12 | santa rosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 3 of set 12 | changzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 4 of set 12 | saravan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 5 of set 12 | te anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 6 of set 12 | moengo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 7 of set 12 | yacuiba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 8 of set 12 | guaruja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 9 of set 12 | caraquet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 10 of set 12 | malbork
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 11 of set 12 | madimba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 12 of set 12 | salinas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 13 of set 12 | hirara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 14 of set 12 | ondorhaan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# Processing record 15 of set 12 | harfleur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 16 of set 12 | hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# Processing record 17 of set 12 | phan rang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1cdc9d399acb2599e977cf6d6763d8ed
# City not found!
# -------------------------
# Data Retrieval Complete
# -------------------------

# %%
# create a data frame from cities, temp, humidity, cloudiness and wind speed
weather_dict = {
    "City": new_cities,
    "Cloudiness" : cloudiness,
    "Country" : country,
    "Date" : date,
    "Humidity" : humidity,
    "Temp": temp,
    "Lat" : lat,
    "Lng" : lng,   
    "Wind Speed" : wind
}
weather_data = pd.DataFrame(weather_dict)
weather_data.count()
# Out:
# City          583
# Cloudiness    583
# Country       583
# Date          583
# Humidity      583
# Temp          583
# Lat           583
# Lng           583
# Wind Speed    583
# dtype: int64

# %%
weather_data.head()
# Out:
#          City  Cloudiness Country        Date  Humidity   Temp    Lat     Lng  \
# 0      atuona           0      PF  1592336575        77  80.47  -9.80 -139.03
# 1       bluff          43      NZ  1592336777        75  54.19 -46.60  168.33
# 2        lebu         100      CL  1592336777        90  53.10 -37.62  -73.65
# 3  butaritari           3      KI  1592336777        80  83.10   3.07  172.79
# 4       chara          56      RU  1592336778        76  55.49  56.91  118.26
#
#    Wind Speed
# 0       19.80
# 1       14.83
# 2       15.95
# 3       13.38
# 4        2.26

# %%
cities_list = zip(new_cities,cloudiness,country,date,humidity,temp,lat,lng)
# Set variable for output file
output_file = os.path.join('..', 'API code', 'cities1.csv')
#  Open the output file
with open(output_file, 'w') as datafile:
    weather_data.to_csv(output_file)

# %%
date =datetime.datetime.fromtimestamp(
        int(weather_data['Date'][0])
    ).strftime('%m/%d/%Y')

# %%
# Latitude Vs Temperature Plot

weather_data.plot(kind='scatter', x='Lat', y='Temp', c='DarkBlue')
plt.title('City Latitude Vs Max Temperature ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Max temperature (F)')
plt.grid()

# %%
# Latitude Vs Humidity

weather_data.plot(kind='scatter',x='Lat',y='Humidity', c='DarkBlue')
plt.title('City Latitude Vs Max Humidity ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()

# %%
# Latitude Vs Cloudiness

weather_data.plot(kind='scatter',x='Lat',y='Cloudiness', c='DarkBlue')
plt.title('City Latitude Vs Cloudiness ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()

# %%
# Latitude Vs Wind Speed

weather_data.plot(kind='scatter',x='Lat',y='Wind Speed', c='DarkBlue')
plt.title('City Latitude Vs Wind Speed ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid()
