# %%
import os
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import gmaps
from pprint import pprint
import datetime

# %%
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
#         if len(cities)<100:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 628

# %%
new_cities = []
cloudiness = []
country = []
date = []
humidity = []
temp = []
lat = []
lng = []
wind = []

# %%
api_key=''

# %%
record_counter = 0
set_counter = 0
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 
print('------------------------')
print('Beginning Data Retrieval')
print('------------------------')

for city in cities:
    query_url = url + "&q=" + city
    # Get weather data
    response = requests.get(query_url).json()
    if record_counter < 50:
        record_counter += 1
    else:
        set_counter += 1
        record_counter = 0

    print('Processing record {} of set {} | {}'.format(record_counter, set_counter, city))
    print(url)
    try:
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        temp.append(response['main']['temp_max'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        wind.append(response['wind']['speed'])
        new_cities.append(city)
    except:
        print("City not found!")
        pass

print('-------------------------')
print('Data Retrieval Complete')
print('-------------------------')
# Out:
# ------------------------
# Beginning Data Retrieval
# ------------------------
# Processing record 1 of set 0 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 2 of set 0 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 3 of set 0 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 4 of set 0 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 5 of set 0 | teruel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 6 of set 0 | inderborskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 7 of set 0 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 8 of set 0 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 9 of set 0 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 10 of set 0 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 11 of set 0 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 12 of set 0 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 13 of set 0 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 14 of set 0 | lafiagi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 15 of set 0 | ranfurly
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 16 of set 0 | goiania
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 17 of set 0 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 18 of set 0 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 19 of set 0 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 20 of set 0 | karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 21 of set 0 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 22 of set 0 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 23 of set 0 | pyaozerskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 24 of set 0 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 25 of set 0 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 26 of set 0 | sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 27 of set 0 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 28 of set 0 | burnie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 29 of set 0 | sarishabari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 30 of set 0 | beloha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 31 of set 0 | westport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 32 of set 0 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 33 of set 0 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 34 of set 0 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 35 of set 0 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 36 of set 0 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 37 of set 0 | oranzherei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 38 of set 0 | sioux lookout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 39 of set 0 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 40 of set 0 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 41 of set 0 | turukhansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 42 of set 0 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 43 of set 0 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 44 of set 0 | saint-louis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 45 of set 0 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 46 of set 0 | ous
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 47 of set 0 | bambanglipuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 48 of set 0 | lityn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 49 of set 0 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 50 of set 0 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 0 of set 1 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 1 of set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 2 of set 1 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 3 of set 1 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 4 of set 1 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 5 of set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 6 of set 1 | mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 7 of set 1 | santa cruz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 8 of set 1 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 9 of set 1 | kasiri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 10 of set 1 | kuche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 11 of set 1 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 12 of set 1 | zeya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 13 of set 1 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 14 of set 1 | kisangani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 15 of set 1 | tocopilla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 16 of set 1 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 17 of set 1 | maryborough
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 18 of set 1 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 19 of set 1 | muroto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 20 of set 1 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 21 of set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 22 of set 1 | harper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 23 of set 1 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 24 of set 1 | sipovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 25 of set 1 | mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 26 of set 1 | nelson bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 27 of set 1 | killybegs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 28 of set 1 | poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 29 of set 1 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 30 of set 1 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 31 of set 1 | yirol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 32 of set 1 | blythe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 33 of set 1 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 34 of set 1 | college
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 35 of set 1 | aflu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 36 of set 1 | olinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 37 of set 1 | fukue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 38 of set 1 | maningrida
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 39 of set 1 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 40 of set 1 | lamesa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 41 of set 1 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 42 of set 1 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 43 of set 1 | laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 44 of set 1 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 45 of set 1 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 46 of set 1 | gombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 47 of set 1 | yumen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 48 of set 1 | trincomalee
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 49 of set 1 | umm lajj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 50 of set 1 | fereydun kenar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 0 of set 2 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 1 of set 2 | vila do maio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 2 of set 2 | north bend
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 3 of set 2 | taburi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 4 of set 2 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 5 of set 2 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 6 of set 2 | phek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 7 of set 2 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 8 of set 2 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 9 of set 2 | yazman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 10 of set 2 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 11 of set 2 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 12 of set 2 | princeville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 13 of set 2 | surin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 14 of set 2 | amapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 15 of set 2 | sangar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 16 of set 2 | severnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 17 of set 2 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 18 of set 2 | ballina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 19 of set 2 | solnechnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 20 of set 2 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 21 of set 2 | marang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 22 of set 2 | port blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 23 of set 2 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 24 of set 2 | batagay-alyta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 25 of set 2 | atasu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 26 of set 2 | kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 27 of set 2 | bull savanna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 28 of set 2 | cody
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 29 of set 2 | panzhihua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 30 of set 2 | okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 31 of set 2 | mackay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 32 of set 2 | port hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 33 of set 2 | grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 34 of set 2 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 35 of set 2 | maceio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 36 of set 2 | whitefish
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 37 of set 2 | choma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 38 of set 2 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 39 of set 2 | progreso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 40 of set
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 25 of set 11 | virginia beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 26 of set 11 | maungatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 27 of set 11 | puerto el triunfo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 28 of set 11 | aripuana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 29 of set 11 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 30 of set 11 | marzuq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 31 of set 11 | koygorodok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 32 of set 11 | carlisle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 33 of set 11 | mayumba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 34 of set 11 | wallasey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 35 of set 11 | shuyskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 36 of set 11 | kaoma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 37 of set 11 | gazojak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 38 of set 11 | marfino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 39 of set 11 | baiyin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 40 of set 11 | shieli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 41 of set 11 | yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 42 of set 11 | hunza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 43 of set 11 | anzio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 44 of set 11 | yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 45 of set 11 | dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 46 of set 11 | nsanje
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 47 of set 11 | ulladulla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 48 of set 11 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 49 of set 11 | labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 50 of set 11 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 0 of set 12 | hoa binh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 1 of set 12 | ilhabela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 2 of set 12 | bakal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 3 of set 12 | kawana waters
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 4 of set 12 | balkhash
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 5 of set 12 | talara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 6 of set 12 | birjand
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 7 of set 12 | mitu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 8 of set 12 | manzil salim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 9 of set 12 | hay river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 10 of set 12 | gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 11 of set 12 | port keats
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 12 of set 12 | wynyard
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 13 of set 12 | ngunguru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 14 of set 12 | grand-bourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 15 of set 12 | buin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# Processing record 16 of set 12 | flin flon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=
# City not found!
# -------------------------
# Data Retrieval Complete
# -------------------------

# %%
# create a data frame from cities, temp, humidity, cloudiness and wind speed
weather_dict = {
    "City": new_cities,
    "Cloudiness" : cloudiness,
    "Country" : country,
    "Date" : date,
    "Humidity" : humidity,
    "Temp": temp,
    "Lat" : lat,
    "Lng" : lng,   
    "Wind Speed" : wind
}
weather_data = pd.DataFrame(weather_dict)
weather_data.count()
# Out:
# City          0
# Cloudiness    0
# Country       0
# Date          0
# Humidity      0
# Temp          0
# Lat           0
# Lng           0
# Wind Speed    0
# dtype: int64

# %%
weather_data.head()
# Out:
# Empty DataFrame
# Columns: [City, Cloudiness, Country, Date, Humidity, Temp, Lat, Lng, Wind Speed]
# Index: []

# %%
cities_list = zip(new_cities,cloudiness,country,date,humidity,temp,lat,lng)
# Set variable for output file
output_file = os.path.join('..', 'API code', 'cities2.csv')
#  Open the output file
with open(output_file, 'w') as datafile:
    weather_data.to_csv(output_file)

# %%
date =datetime.datetime.fromtimestamp(
        int(weather_data['Date'][0])
    ).strftime('%m/%d/%Y')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4406         except KeyError as e1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-023c38135133> in <module>
#       1 date =datetime.datetime.fromtimestamp(
# ----> 2         int(weather_data['Date'][0])
#       3     ).strftime('%m/%d/%Y')
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4409
#    4410             try:
# -> 4411                 return libindex.get_value_at(s, key)
#    4412             except IndexError:
#    4413                 raise
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_at()
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_at()
#
# pandas\_libs\util.pxd in pandas._libs.util.get_value_at()
#
# pandas\_libs\util.pxd in pandas._libs.util.validate_indexer()
#
# IndexError: index out of bounds

# %%
# Latitude Vs Temperature Plot

weather_data.plot(kind='scatter', x='Lat', y='Temp', c='DarkBlue')
plt.title('City Latitude Vs Max Temperature ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Max temperature (F)')
plt.grid()

# %%
# Latitude Vs Humidity

weather_data.plot(kind='scatter',x='Lat',y='Humidity', c='DarkBlue')
plt.title('City Latitude Vs Max Humidity ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()

# %%
# Latitude Vs Cloudiness

weather_data.plot(kind='scatter',x='Lat',y='Cloudiness', c='DarkBlue')
plt.title('City Latitude Vs Cloudiness ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()

# %%
# Latitude Vs Wind Speed

weather_data.plot(kind='scatter',x='Lat',y='Wind Speed', c='DarkBlue')
plt.title('City Latitude Vs Wind Speed ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid()
